# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.metrics import r2_score
np.random.seed(0)

# %%
os.chdir("FirstPart0.85")
os.getcwd()
# Out:
# '/local0/t_wand01/GLE for Finance/FirstPart0.85'

# %%
from os import listdir

directory_path = '.'
file_types = ['npy', 'npz']

np_vars = {dir_content: np.load(dir_content)
           for dir_content in listdir(directory_path)
           if dir_content.split('.')[-1] in file_types}

# %%
for i in np_vars.keys():
    print(i)
# Out:
# theta_meanEst_B10_K0.npy
# MCMCsamples_B10_K3.npy
# SecondPart_0.85WeeklyCorr.npy
# simulatedDataX_B10_K3_MAP.npy
# credibleIntervals_B10_K3.npy
# FirstPart_0.85WeeklyCorr.npy
# theta_MAPest_B10_K3.npy
# theta_direct_SLE_B10.npy
# theta_MAPest_B10_K0.npy
# n_bin_B10_K0.npy
# binsX_B10.npy
# credibleIntervals_B10_K0.npy
# n_bin_B10_K3.npy
# coeff_B10_K0.npy
# MCMCsamples_B10_K0.npy
# simulatedDataX_B10_K0_MAP.npy
# coeff_B10_K3.npy
# theta_meanEst_B10_K3.npy
# edgesX_B10.npy
# simulatedDataX_B10_K0_mean.npy
# MCMCsamples_raw_B10_K0.npy
# MCMCsamples_raw_B10_K3.npy

# %%
os.chdir("..")
os.getcwd()
# Out:
# '/local0/t_wand01/GLE for Finance'

# %%
os.chdir("Predict")
os.getcwd()
# Out:
# '/local0/t_wand01/GLE for Finance/Predict'

# %% [markdown]
# ## Edges of the Bins for Input Time Series Data

# %%
np_vars["edgesX_B10.npy"]
# Out:
# array([0.00523525, 0.08627032, 0.16730539, 0.24834046, 0.32937553,
#        0.4104106 , 0.49144567, 0.57248073, 0.6535158 , 0.73455087,
#        0.81558594])

# %% [markdown]
# ## Estimated Parameters
#
# - First ten parameters are for $D^{(1)}$
# - Second ten parameters are for $D^{(2)}$
# - Last remaining parameters are for Kernel $\mathcal{K}$

# %%
print(np.round(np_vars["theta_MAPest_B10_K3.npy"],3))
# Out:
# [ 0.036  0.012 -0.002  0.005 -0.015 -0.072 -0.064 -0.063 -0.015 -0.013
#   0.009  0.01   0.014  0.019  0.021  0.027  0.018  0.034  0.037  0.022
#  -0.244 -0.163 -0.184]

# %%
# Into a pd.DataFrame

D1D2 = pd.DataFrame({"D1": np_vars["theta_MAPest_B10_K3.npy"][0:10],
                    "D2": np_vars["theta_MAPest_B10_K3.npy"][10:20]})

D1D2_0 = pd.DataFrame({"D1": np_vars["theta_MAPest_B10_K0.npy"][0:10],
                    "D2": np_vars["theta_MAPest_B10_K0.npy"][10:20]})

D1D2.head(), D1D2_0.head()
# Out:
# (         D1        D2
#  0  0.036162  0.009214
#  1  0.012170  0.009988
#  2 -0.002284  0.013724
#  3  0.004641  0.018958
#  4 -0.015349  0.020773,
#           D1        D2
#  0  0.077641  0.011177
#  1  0.038694  0.013669
#  2  0.003427  0.017781
#  3 -0.012006  0.026442
#  4 -0.050746  0.025757)

# %% [markdown]
# Ensure that Kernel[1] is actually the lag-1-Kernel by adding a zeroth element

# %%
Kernel = [0]
Kernel += list(np_vars["theta_MAPest_B10_K3.npy"][20:])
print(np.round(Kernel,3))
# Out:
# [ 0.    -0.244 -0.163 -0.184]

# %% [markdown]
# ## Prediction
#
# Taken from Eq. (7) in Clemens's Preprint

# %%
def getBin(x, Binning):
    # get Bin for observation x via Binning intervals Binning,
    # starts with zeroth Bin
    
    Output = int(sum(x>Binning)) - 1  
    # -1 because lowest interval boundary is minimum
    
    Output = max(0, Output) # if lower than min. in training data
    Output = min(len(Binning)-2, Output) # if higher than max. in training: N interval boundaries-> N-2 intervals
    
    return(int(Output))

    
    
getBin(0.36,np_vars["edgesX_B10.npy"])
# Out:
# 4

# %%
print(np.round(np_vars["edgesX_B10.npy"],3))
# Out:
# [0.005 0.086 0.167 0.248 0.329 0.41  0.491 0.572 0.654 0.735 0.816]

# %%
# This gives me mean and standard deviation of the prediction

def Prediction_mean_std(X_in, d1d2_DF, Kernels, Binning, deltaT, K):
    
    
    assert type(K) == int
    
    Interval = getBin(X_in[-1], Binning)
    
    Output_m = X_in[-1]  # past value
    Output_m +=  d1d2_DF["D1"].loc[Interval] * deltaT # simple Euler ODE
    
    # now for the kernel
    
    for k in range(1,K+1): # sum over 1 to (inclusive) K
        Contribution = 0
        Contribution += Kernel[k] * ( X_in[-1] - X_in[-1-k])*deltaT
        Output_m += Contribution # Kernel effect
    
    # now the stochastic Ito-component
    Output_std = float(np.sqrt(d1d2_DF["D2"].loc[Interval] * deltaT))

        
    return( np.array([Output_m, Output_std]) )

# %% [markdown]
# ## Test

# %%
X = np_vars["FirstPart_0.85WeeklyCorr.npy"]

# %%
Prediction_mean_std(X[:-1], D1D2_0, Kernel, Binning=np_vars["edgesX_B10.npy"],
                           deltaT = 1, K = 3)
# Out:
# array([0.28601712, 0.16132169])

# %%
Prediction_mean_std(X, D1D2, Kernel, Binning=np_vars["edgesX_B10.npy"],
                           deltaT = 1, K = 3)
# Out:
# array([0.41466195, 0.13768674])

# %%
m, std = Prediction_mean_std(X, D1D2, Kernel, Binning=np_vars["edgesX_B10.npy"],
                           deltaT = 1, K = 3)
print(m,std)
# Out:
# 0.41466194553719815 0.13768674008447276

# %% [markdown]
# # In-Sample Prediction

# %%
K_Length = 3

# %%
Means = list()
Stds = list()
TrueValues = list()
LastValues = list()
L = len(X)-K_Length-1


for i in range(L):
    TrueValues = TrueValues +  [X[-L+i+1]]
    LastValues = LastValues+  [X[-L+i]]
    mn, st = Prediction_mean_std(X[:-L+i], D1D2, Kernel, Binning=np_vars["edgesX_B10.npy"],
                           deltaT = 1, K = K_Length)
   
    Means = Means + [mn]
    Stds = Stds + [st]

# %%
np.array(Stds).flatten()
# Out:
# array([0.09598783, 0.09994201, 0.11715135, 0.09994201, 0.09598783,
#        0.09994201, 0.09598783, 0.09598783, 0.09994201, 0.14412804,
#        0.09994201, 0.09598783, 0.09994201, 0.09598783, 0.09994201,
#        0.09598783, 0.09994201, 0.09598783, 0.09994201, 0.11715135,
#        0.09994201, 0.09994201, 0.09598783, 0.09598783, 0.09994201,
#        0.09994201, 0.09598783, 0.09598783, 0.09994201, 0.09598783,
#        0.09994201, 0.13768674, 0.09994201, 0.09994201, 0.09994201,
#        0.11715135, 0.09598783, 0.09598783, 0.09994201, 0.09598783,
#        0.09994201, 0.09598783, 0.09598783, 0.09994201, 0.09994201,
#        0.09598783, 0.09598783, 0.09994201, 0.09598783, 0.09598783,
#        0.09994201, 0.09994201, 0.13768674, 0.09598783, 0.09994201,
#        0.09994201, 0.09994201, 0.09994201, 0.09598783, 0.11715135,
#        0.09994201, 0.09598783, 0.09994201, 0.09598783, 0.09598783,
#        0.11715135, 0.09994201, 0.09994201, 0.09598783, 0.09598783,
#        0.09994201, 0.09598783, 0.09994201, 0.09598783, 0.09598783,
#        0.09598783, 0.09598783, 0.09598783, 0.09598783, 0.09598783,
#        0.09598783, 0.11715135, 0.09598783, 0.09994201, 0.09598783,
#        0.09598783, 0.09598783, 0.09598783, 0.09598783, 0.11715135,
#        0.09598783, 0.09994201, 0.09598783, 0.09598783, 0.09598783,
#        0.09994201, 0.09598783, 0.09598783, 0.09994201, 0.09598783,
#        0.09598783, 0.09598783, 0.13768674, 0.09598783, 0.11715135,
#        0.09598783, 0.09994201, 0.09598783, 0.09994201, 0.09994201,
#        0.16514336, 0.09598783, 0.09994201, 0.09994201, 0.09994201,
#        0.09994201, 0.09994201, 0.09598783, 0.09598783, 0.09598783,
#        0.09994201, 0.11715135, 0.09598783, 0.09598783, 0.09994201,
#        0.09598783, 0.09994201, 0.09598783, 0.09994201, 0.09994201,
#        0.09994201, 0.09994201, 0.11715135, 0.09994201, 0.09598783,
#        0.11715135, 0.09994201, 0.09598783, 0.09994201, 0.13768674,
#        0.09994201, 0.09994201, 0.11715135, 0.09994201, 0.09994201,
#        0.09598783, 0.09598783, 0.09598783, 0.09598783, 0.09598783,
#        0.09598783, 0.09598783, 0.09994201, 0.09598783, 0.09994201,
#        0.11715135, 0.09994201, 0.09994201, 0.09598783, 0.09598783,
#        0.09598783, 0.09598783, 0.09598783, 0.09598783, 0.09598783,
#        0.09598783, 0.11715135, 0.09598783, 0.11715135, 0.09994201,
#        0.09598783, 0.09994201, 0.09994201, 0.09598783, 0.09598783,
#        0.11715135, 0.09994201, 0.09598783, 0.09994201, 0.09598783,
#        0.09598783, 0.09598783, 0.09598783, 0.09598783, 0.09598783,
#        0.09994201, 0.09598783, 0.09598783, 0.09598783, 0.09994201,
#        0.09598783, 0.09598783, 0.09598783, 0.09598783, 0.09598783,
#        0.09598783, 0.09994201, 0.09598783, 0.09994201, 0.11715135,
#        0.09598783, 0.09994201, 0.09994201, 0.09598783, 0.09598783,
#        0.14412804, 0.11715135, 0.16514336, 0.11715135, 0.09598783,
#        0.09598783, 0.11715135, 0.11715135, 0.09598783, 0.09598783,
#        0.09994201, 0.09598783, 0.09598783, 0.09994201, 0.09994201,
#        0.09598783, 0.09598783, 0.09994201, 0.09994201, 0.13768674,
#        0.14412804, 0.09994201, 0.11715135, 0.11715135, 0.09994201,
#        0.09598783, 0.09994201, 0.11715135, 0.09994201, 0.09598783,
#        0.09598783, 0.09994201, 0.09994201, 0.09598783, 0.09598783,
#        0.09598783, 0.09598783, 0.09598783, 0.09598783, 0.09994201,
#        0.11715135, 0.09598783, 0.09994201, 0.11715135, 0.11715135,
#        0.09994201, 0.09598783, 0.09994201, 0.11715135, 0.09994201,
#        0.11715135, 0.11715135, 0.09994201, 0.11715135, 0.09994201,
#        0.13768674, 0.11715135, 0.14412804, 0.09598783, 0.11715135,
#        0.13768674, 0.13768674, 0.11715135, 0.09994201, 0.09598783,
#        0.09994201, 0.09994201, 0.11715135, 0.11715135, 0.09994201,
#        0.09994201, 0.13768674, 0.09598783, 0.09994201, 0.13768674,
#        0.13768674, 0.11715135, 0.14412804, 0.09994201, 0.14412804,
#        0.09994201, 0.09994201, 0.11715135, 0.09598783, 0.14412804,
#        0.19121377, 0.14412804, 0.11715135, 0.13768674, 0.13768674,
#        0.09994201, 0.11715135, 0.09994201, 0.09994201, 0.11715135,
#        0.13768674, 0.11715135, 0.09994201, 0.11715135, 0.09994201,
#        0.09598783, 0.11715135, 0.09598783, 0.13768674, 0.09598783,
#        0.09598783, 0.09994201, 0.11715135, 0.11715135, 0.11715135,
#        0.16514336, 0.09994201, 0.09994201, 0.09994201, 0.11715135,
#        0.11715135, 0.09994201, 0.13768674, 0.09994201, 0.09994201,
#        0.09994201, 0.09994201, 0.09994201, 0.13768674, 0.14412804,
#        0.14412804, 0.11715135, 0.16514336, 0.14412804, 0.14412804,
#        0.11715135, 0.13768674, 0.13768674, 0.11715135, 0.09994201,
#        0.09598783, 0.09994201, 0.09994201, 0.09994201, 0.09994201,
#        0.11715135, 0.13768674, 0.09994201, 0.09994201, 0.09598783,
#        0.09994201, 0.13768674, 0.09598783, 0.09994201, 0.09994201,
#        0.11715135, 0.11715135, 0.09598783, 0.11715135, 0.09598783,
#        0.13768674, 0.13768674, 0.09994201, 0.09598783, 0.09598783,
#        0.09598783, 0.11715135, 0.09598783, 0.11715135, 0.09994201,
#        0.11715135, 0.11715135, 0.09994201, 0.09598783, 0.09598783,
#        0.09598783, 0.09598783, 0.09994201, 0.09994201, 0.09598783,
#        0.13768674, 0.11715135, 0.11715135, 0.16514336, 0.09598783,
#        0.09994201, 0.11715135, 0.09994201, 0.09994201, 0.11715135,
#        0.09994201, 0.13768674, 0.09598783, 0.09598783, 0.09994201,
#        0.09994201, 0.11715135, 0.09598783, 0.09598783, 0.09598783,
#        0.13768674, 0.11715135, 0.09994201, 0.09994201, 0.11715135,
#        0.09994201, 0.09994201, 0.09994201, 0.09598783, 0.11715135,
#        0.13480712, 0.09994201, 0.09994201, 0.09598783, 0.16514336,
#        0.09598783, 0.11715135, 0.09994201, 0.11715135, 0.09994201,
#        0.11715135, 0.09994201, 0.09598783, 0.09598783, 0.09598783,
#        0.09994201, 0.09598783, 0.09598783, 0.09994201, 0.09994201,
#        0.09598783, 0.09994201, 0.09598783, 0.09598783, 0.09598783,
#        0.09598783, 0.09598783, 0.09994201, 0.09598783, 0.09994201,
#        0.09994201, 0.09598783, 0.11715135, 0.09598783, 0.09994201,
#        0.09994201, 0.09598783, 0.09994201, 0.09598783, 0.11715135,
#        0.13768674, 0.09994201, 0.09598783, 0.09994201, 0.09598783,
#        0.09598783, 0.09598783, 0.09598783, 0.11715135, 0.09598783,
#        0.13768674, 0.13768674, 0.11715135, 0.14412804, 0.14412804,
#        0.11715135, 0.09994201, 0.11715135, 0.09598783, 0.13768674,
#        0.11715135, 0.11715135, 0.11715135, 0.11715135, 0.09994201,
#        0.09598783, 0.11715135, 0.09994201, 0.11715135, 0.09994201,
#        0.09994201, 0.13768674, 0.09994201, 0.11715135, 0.09994201,
#        0.13768674, 0.14412804, 0.13768674, 0.11715135, 0.13768674,
#        0.13768674, 0.14412804, 0.09994201, 0.11715135, 0.09598783,
#        0.13768674, 0.13768674, 0.09994201, 0.09994201, 0.09994201,
#        0.09994201, 0.09598783, 0.11715135, 0.09598783, 0.16514336,
#        0.11715135, 0.13768674, 0.09994201, 0.13768674, 0.11715135,
#        0.11715135, 0.13768674, 0.11715135, 0.09994201, 0.14412804,
#        0.09994201, 0.13768674, 0.14412804, 0.14412804, 0.11715135,
#        0.13768674, 0.16514336, 0.11715135, 0.16514336, 0.11715135,
#        0.13480712, 0.11715135, 0.13768674, 0.13480712, 0.18359742,
#        0.18359742, 0.16514336, 0.16514336, 0.13768674, 0.18359742,
#        0.14412804, 0.13768674, 0.13480712, 0.16514336, 0.13480712,
#        0.16514336, 0.13768674, 0.11715135, 0.14412804, 0.13768674,
#        0.11715135, 0.16514336, 0.14412804, 0.16514336, 0.13768674,
#        0.19121377, 0.16514336, 0.09994201, 0.16514336, 0.16514336,
#        0.09994201, 0.16514336, 0.13480712, 0.13768674, 0.16514336,
#        0.18359742, 0.18359742, 0.14412804, 0.14412804, 0.16514336,
#        0.14412804, 0.14412804, 0.13768674, 0.14412804, 0.16514336,
#        0.11715135, 0.13768674, 0.14412804, 0.16514336, 0.11715135,
#        0.11715135, 0.16514336, 0.11715135, 0.14412804, 0.13768674,
#        0.14412804, 0.11715135, 0.09598783, 0.14412804, 0.13768674,
#        0.14412804, 0.13768674, 0.13768674, 0.16514336, 0.09994201,
#        0.13768674, 0.11715135, 0.09994201, 0.11715135, 0.13768674,
#        0.13768674, 0.11715135, 0.11715135, 0.14412804, 0.11715135,
#        0.13768674, 0.09994201, 0.11715135, 0.09994201, 0.11715135,
#        0.09598783, 0.13768674, 0.13768674, 0.09994201, 0.11715135,
#        0.13480712, 0.13480712, 0.16514336, 0.09994201, 0.11715135,
#        0.14412804, 0.16514336, 0.14412804, 0.13768674, 0.13768674,
#        0.09994201, 0.13768674, 0.16514336, 0.16514336, 0.11715135,
#        0.09994201, 0.11715135, 0.09598783, 0.13768674, 0.13768674,
#        0.14412804, 0.16514336, 0.16514336, 0.11715135, 0.14412804,
#        0.11715135, 0.09994201, 0.14412804, 0.13768674, 0.14412804,
#        0.13768674, 0.11715135, 0.11715135, 0.13768674, 0.11715135,
#        0.13768674, 0.11715135, 0.13768674, 0.14412804, 0.09994201,
#        0.14412804, 0.14412804, 0.11715135, 0.14412804, 0.11715135,
#        0.11715135, 0.13768674, 0.09598783, 0.13480712, 0.11715135,
#        0.14412804, 0.14412804, 0.09994201, 0.14412804, 0.13768674,
#        0.16514336, 0.13480712, 0.16514336, 0.13768674, 0.14412804,
#        0.11715135, 0.11715135, 0.13768674, 0.09598783, 0.09994201,
#        0.11715135, 0.14412804, 0.14412804, 0.09994201, 0.13768674,
#        0.11715135, 0.13768674, 0.16514336, 0.09994201, 0.13768674,
#        0.13768674, 0.13768674, 0.13768674, 0.09598783, 0.16514336,
#        0.09994201, 0.13768674, 0.16514336, 0.16514336, 0.09598783,
#        0.11715135, 0.09994201, 0.14412804, 0.09598783, 0.09994201,
#        0.11715135, 0.13768674, 0.09994201, 0.09994201, 0.14412804,
#        0.09994201, 0.09994201, 0.11715135, 0.11715135, 0.13768674,
#        0.09994201, 0.11715135, 0.11715135, 0.13768674, 0.09994201,
#        0.11715135, 0.14412804, 0.09598783, 0.09598783, 0.16514336,
#        0.13768674, 0.13768674, 0.18359742, 0.13768674, 0.13480712,
#        0.14412804, 0.13480712, 0.13768674, 0.13768674, 0.13480712,
#        0.13768674, 0.09994201, 0.11715135, 0.13768674, 0.11715135,
#        0.09598783, 0.14412804, 0.09598783, 0.13768674, 0.09598783,
#        0.11715135, 0.11715135, 0.09598783, 0.09994201, 0.13768674,
#        0.09994201, 0.09598783, 0.13480712, 0.13768674, 0.09598783,
#        0.11715135, 0.14412804, 0.11715135, 0.09598783, 0.09994201,
#        0.13768674, 0.09994201, 0.13768674, 0.09994201, 0.19121377,
#        0.18359742, 0.18359742, 0.16514336, 0.11715135, 0.09994201,
#        0.13768674, 0.09994201, 0.11715135, 0.13768674, 0.16514336,
#        0.11715135, 0.13768674, 0.09598783, 0.19121377, 0.13480712,
#        0.16514336, 0.11715135, 0.11715135, 0.13480712, 0.13768674,
#        0.18359742, 0.18359742, 0.14412804, 0.13480712, 0.16514336,
#        0.14830986, 0.18359742, 0.18359742, 0.13768674, 0.13768674,
#        0.13768674, 0.11715135, 0.13480712, 0.09994201, 0.13480712,
#        0.18359742, 0.13768674, 0.19121377, 0.13768674, 0.18359742,
#        0.14412804, 0.13480712, 0.14412804, 0.14412804, 0.16514336,
#        0.13768674, 0.13768674, 0.13480712, 0.14412804, 0.16514336,
#        0.14412804, 0.19121377, 0.18359742, 0.16514336, 0.18359742,
#        0.09994201, 0.13480712, 0.13768674, 0.09994201, 0.16514336,
#        0.13768674, 0.14412804, 0.14412804, 0.14412804, 0.13480712,
#        0.14412804, 0.16514336, 0.11715135, 0.14412804, 0.11715135,
#        0.11715135, 0.16514336, 0.13480712, 0.11715135, 0.14412804,
#        0.18359742, 0.16514336, 0.18359742, 0.19121377, 0.14830986,
#        0.18359742, 0.19121377, 0.19121377, 0.13768674, 0.18359742,
#        0.14830986, 0.14830986, 0.14830986, 0.14830986, 0.13480712,
#        0.18359742, 0.09994201, 0.16514336, 0.13480712, 0.14412804,
#        0.18359742, 0.13480712, 0.13768674, 0.18359742, 0.14412804,
#        0.18359742, 0.13480712, 0.13480712, 0.19121377, 0.18359742,
#        0.14412804, 0.13480712, 0.13480712, 0.09994201, 0.13768674,
#        0.13768674, 0.18359742, 0.18359742, 0.16514336, 0.09994201,
#        0.16514336, 0.16514336, 0.16514336, 0.13480712, 0.16514336,
#        0.14412804, 0.09994201, 0.13768674, 0.14412804, 0.18359742,
#        0.14412804, 0.16514336, 0.09994201, 0.11715135, 0.11715135,
#        0.18359742, 0.11715135, 0.13768674, 0.16514336, 0.19121377])

# %% [markdown]
# ##### For no Memory

# %%
Means_0 = list()
Stds_0 = list()
TrueValues_0 = list()
LastValues_0 = list()
K_Length_0 = 0
L_0 = len(X)-K_Length_0-1


for i in range(L_0):
    TrueValues_0 = TrueValues_0 +  [X[-L_0+i+1]]
    mn, st = Prediction_mean_std(X[:-L_0+i], D1D2_0, Kernel, Binning=np_vars["edgesX_B10.npy"],
                           deltaT = 1, K = K_Length_0)
   
    Means_0 = Means_0 + [mn]
    Stds_0 = Stds_0 + [st]

# %% [markdown]
# ### Some Confidence Interval Checks

# %%
LowerCI = np.array(Means)-np.array(Stds) 
UpperCI = np.array(Means)+np.array(Stds) 
ArrayTrueValues = np.array(TrueValues)

LCI_Check = 1.0*(LowerCI<ArrayTrueValues)
UCI_Check =1.0*(UpperCI>ArrayTrueValues)

InCI = LCI_Check * UCI_Check
print(np.mean(InCI))
# Out:
# 0.6871508379888268

# %%
len(TrueValues)
# Out:
# 895

# %%
len(X)
# Out:
# 899

# %%
plt.scatter(TrueValues, LastValues, label="Naive Prediction")
plt.xlabel("True Values")
plt.ylabel("Last Values")
plt.plot([0,1],[0,1], label="Identity", c ="r")
plt.legend()
plt.show()

# %%
plt.scatter(TrueValues, LastValues, label="Naive Forecast", alpha = 0.5)
#plt.scatter(TrueValues_0, Means_0, label="Langevin without Kernel", alpha = 0.5)
plt.scatter(TrueValues, Means, label="Kernel Forecast", alpha = 0.5)

fs = 14
plt.xlabel("True Values: Market Correlation",fontsize = fs)
plt.ylabel("One-Step Forecasts",fontsize = fs)
plt.plot([0,1],[0,1], label="Identity", c ="k")
plt.legend()
plt.show()

# %% [markdown]
# #### Root Mean Square Error and R² Metrics

# %%
np.sqrt(np.mean((np.array(TrueValues)-np.array(Means))**2.))
# Out:
# 0.12678415495553852

# %%
np.sqrt(np.mean((np.array(TrueValues)-np.array(LastValues))**2.))
# Out:
# 0.15410564391530576

# %% [markdown]
# R^2 of GLE

# %%
r2_score(y_true=TrueValues, y_pred=Means)
# Out:
# 0.42457732181013397

# %% [markdown]
# R² of LE

# %%
r2_score(y_true=TrueValues_0, y_pred=Means_0) #0.3487483090652824
# Out:
# 0.3209098714594022

# %% [markdown]
# R² of Naive

# %%
r2_score(y_true=TrueValues, y_pred=LastValues)
# Out:
# 0.14985285178580154

# %% [markdown]
# # Out-Of-Sample Prediction

# %%
test_data = np_vars["SecondPart_0.85WeeklyCorr.npy"]
len(test_data)
# Out:
# 158

# %%
plt.plot(test_data)
plt.show()

# %%
X_full = np.concatenate([X,test_data])
plt.plot(X)
plt.plot(np.arange( len(X), len(X)+len(test_data)),
        test_data)
plt.show()

# %%
len(test_data)
# Out:
# 158

# %%
Means_test = list()
Stds_test = list()
TrueValues_test = list()
LastValues_test = list()
L = len(test_data)+1  # +1 because first TrueValues is [X[-L+i+1]]


for i in range(L):
    TrueValues_test = TrueValues_test +  [X_full[-L+i+1]]
    LastValues_test = LastValues_test+  [X_full[-L+i]]
    mn, st = Prediction_mean_std(X_full[:-L+i], D1D2, Kernel, Binning=np_vars["edgesX_B10.npy"],
                           deltaT = 1, K = K_Length)
   
    Means_test = Means_test + [mn]
    Stds_test = Stds_test + [st]

# %%
len(X_full)
# Out:
# 1057

# %%
plt.plot(X_full[:-L_0])

# %% [markdown]
# ##### For no Memory

# %%
Means_0_test = list()
Stds_0_test = list()
TrueValues_0_test = list()
LastValues_0_test = list()
K_Length_0 = 0
L_0 = len(test_data)+1  # +1 because first TrueValues is [X[-L+i+1]]

print(L_0-1)
for i in range(L_0):

    mn, st = Prediction_mean_std(X_full[:-L_0+i], D1D2_0, Kernel, Binning=np_vars["edgesX_B10.npy"],
                           deltaT = 1, K = K_Length_0)
   
    TrueValues_0_test = TrueValues_0_test +  [X_full[-L+i+1]]
    Means_0_test = Means_0_test + [mn]
    Stds_0_test = Stds_0_test + [st]
# Out:
# 158

# %%
len(TrueValues_0_test), len(Means_0_test), len(TrueValues_test)
# Out:
# (159, 159, 159)

# %%
#plt.scatter(TrueValues_test, LastValues_test, label="Naive Forecast", alpha = 0.5)
plt.scatter(TrueValues_0_test, Means_0_test, label="No Kernel", alpha = 0.5)

plt.scatter(TrueValues_test, Means_test, label="Kernel Forecast", alpha = 0.5)

fs = 14
plt.xlabel("True Values: Market Correlation",fontsize = fs)
plt.ylabel("One-Step Forecasts",fontsize = fs)
plt.plot([0,1],[0,1], label="Identity", c ="k")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize = (8,4),sharey=True)


Maximum = max(max(TrueValues), max(TrueValues_0), max(Means_0), max(Means),
              max(TrueValues_test), max(TrueValues_0_test), max(Means_0_test),max(Means_test))


ax[0].scatter(TrueValues_0, Means_0, label="No Kernel", alpha = 0.5)
ax[0].scatter(TrueValues, Means, label="Kernel Forecast", alpha = 0.5)

fs = 12
ax[0].set_xlabel("True Values: Market Correlation",fontsize = fs)
ax[0].set_ylabel("One-Step Forecasts",fontsize = fs)
ax[0].plot([0,Maximum],[0,Maximum], label="Identity", c ="k")
ax[0].set_title("Training Data", fontsize = fs+1)
#ax[0].legend()


ax[1].scatter(TrueValues_0_test, LastValues_test, label="No Kernel", alpha = 0.5)
ax[1].scatter(TrueValues_test, Means_test, label="Kernel Forecast", alpha = 0.5)
ax[1].set_xlabel("True Values: Market Correlation",fontsize = fs)
ax[1].plot([0,Maximum],[0,Maximum], label="Identity", c ="k")
ax[1].set_title("Test Data", fontsize = fs+1)


handles, labels = ax[0].get_legend_handles_labels()
fig.legend(handles, labels, loc=(0.2,0.925),ncol=3, fontsize = fs)

plt.savefig("Prediction_Evaluation.pdf", bbox_inches="tight", dpi = 500)

plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize = (8,4),sharey=True)


Maximum = max(max(TrueValues), max(TrueValues_0), max(Means_0), max(Means),
              max(TrueValues_test), max(TrueValues_0_test), max(LastValues_test))


ax[0].scatter(TrueValues, LastValues, label="Naive", alpha = 0.5)
ax[0].scatter(TrueValues, Means, label="Kernel Forecast", alpha = 0.5)

fs = 12
ax[0].set_xlabel("True Values: Market Correlation",fontsize = fs)
ax[0].set_ylabel("One-Step Forecasts",fontsize = fs)
ax[0].plot([0,Maximum],[0,Maximum], label="Identity", c ="k")
ax[0].set_title("Training Data", fontsize = fs+1)
#ax[0].legend()


ax[1].scatter(TrueValues_test, LastValues_test, label="Naive", alpha = 0.5)
ax[1].scatter(TrueValues_test, Means_test, label="Kernel Forecast", alpha = 0.5)
ax[1].set_xlabel("True Values: Market Correlation",fontsize = fs)
ax[1].plot([0,Maximum],[0,Maximum], label="Identity", c ="k")
ax[1].set_title("Test Data", fontsize = fs+1)


handles, labels = ax[0].get_legend_handles_labels()
fig.legend(handles, labels, loc=(0.2,0.925),ncol=3, fontsize = fs)

plt.savefig("Prediction_Evaluation_Naive.pdf", bbox_inches="tight", dpi = 500)

plt.show()

# %% [markdown]
# #### Root Mean Square Error and R²

# %%
np.sqrt(np.mean((np.array(TrueValues_test)-np.array(Means_test))**2.))
# Out:
# 0.2023439401112965

# %%
np.sqrt(np.mean((np.array(TrueValues_0_test)-np.array(Means_0_test))**2.))
# Out:
# 0.21263812632978996

# %%
np.sqrt(np.mean((np.array(TrueValues_test)-np.array(LastValues_test))**2.))
# Out:
# 0.22692312681799992

# %% [markdown]
# R² of GLE:

# %%
r2_score(y_true=TrueValues_test, y_pred=Means_test)
# Out:
# 0.08490867141705938

# %% [markdown]
# R² of LE:

# %%
r2_score(y_true=TrueValues_0_test, y_pred=Means_0_test) # 0.07228434075280932
# Out:
# -0.010569783903534136

# %% [markdown]
# R^2 of Naive:

# %%
r2_score(y_true=TrueValues_test, y_pred=LastValues_test)
# Out:
# -0.15091050298645148

# %%
Means_test[-1], TrueValues_test[-1]
# Out:
# (0.2642537445683339, 0.11584862290253742)

# %% [markdown]
# ### Again, CIs

# %%
LowerCI_test = np.array(Means_test)-np.array(Stds_test) 
UpperCI_test = np.array(Means_test)+np.array(Stds_test) 
ArrayTrueValues_test = np.array(TrueValues_test)

LCI_Check_test = 1.0*(LowerCI_test<ArrayTrueValues_test)
UCI_Check_test =1.0*(UpperCI_test>ArrayTrueValues_test)

InCI_test = LCI_Check_test * UCI_Check_test
print(np.mean(InCI_test))
# Out:
# 0.5283018867924528
